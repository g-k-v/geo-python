# %% [markdown]
# ## Готовим Python
#
# Это упражнение вдохновлено тем, что Финляндия шестой год подряд считается самой счастливой страной в мире. За пять простых шагов (или задач) мы сможем выявить ваше счастье, основанное на двух самых важных факторах счастья в жизни: мороженом и сне!

# %%
ice_cream_rating = 4
sleep_rating = 9

# %%
first_name = 'Григорий'
last_name = 'Каспаров'
my_name = first_name + ' ' + last_name
print(my_name)
# Out:
# Григорий Каспаров

# %%
happiness_rating = (ice_cream_rating + sleep_rating) / 2

# %%
print(type(ice_cream_rating), type(sleep_rating), type(happiness_rating))
# Out:
# <class 'int'> <class 'int'> <class 'float'>

# %% [markdown]
# Тип данных переменной happiness_rating" оказался для меня неожиданостью, т. к. при процедуре деления int (целое число) на int python выдаёт переменной тип float (¿число с плавающей запятой?)

# %%
print("Меня зовут",first_name+",","и я ставлю мороженому",ice_cream_rating,"баллов из 10! \nЯ", my_name+",", "и мой рейтинг удовольствия от сна —", sleep_rating, "из 10! \nИсходя из вышеперечисленных факторов, мой рейтинг счастья составляет",happiness_rating,"из 10, или", happiness_rating*10,"%!")
# Out:
# Меня зовут Григорий, и я ставлю мороженому 4 баллов из 10!
# Я Григорий Каспаров, и мой рейтинг удовольствия от сна — 9 из 10!
# Исходя из вышеперечисленных факторов, мой рейтинг счастья составляет 6.5 из 10, или 65.0 %!
